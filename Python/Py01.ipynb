# %% [markdown]
# <a href="https://colab.research.google.com/github/jyns417/Aiffel_quest_cr2/blob/master/Python/Py01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python/Quest01
# coder : 김우찬, 김지영

# 회문인지 확인하는 프로그램 작성
# 자료형, 제어문, 함수를 활용한다

# 단어를 입력받기
a = input('원하는 단어를 입력합니다:')

# 회문된 단어와 회문인지 확인하는 함수입니다. w 에 문자열을 입력
def new_word(w):
  i = len(w)
  nw = w[-1:-i-1:-1]   # 새로운 nw 에 w의 -1번째 항목부터 -i-1번째 항목까지 거꾸로(-1씩 올려서) 입력해준다
  print('회문된 단어입니다',nw)
  if nw == w :  # 두 단어가 일치할시 회문으로 확인됨
    print ('회문이 맞습니다')
  else:
    print ('회문이 아닙니다')

new_word(a)
# Out:
# 원하는 단어를 입력합니다:adda
# 회문된 단어입니다 adda
# 회문이 맞습니다
